# %%
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import numpy as np

# %%
dict = {
    'SMAs':['2-8','4-8','2-24','4-24','2-50','4-50','2-80','4-80','4-100','8-100','16-100','24-100','4-120','8-120','16-120','24-120','4-140','8-140','16-140','24-140','4-160','8-160','16-160','24-160','4-200','8-200','16-200','24-200','48-200','4-300','8-300','16-300','24-300','48-300','8-400','24-400','48-400','8-500','24-500','48-500','8-600','24-600','48-600','8-730','24-730','48-730'],
    'CumProd Diff':[-0.269355,-0.269355,-0.299594,-0.299594,-0.303224,-0.303224,-0.355966,-0.355966,-0.354796,-0.354796,-0.354796,-0.354796,-0.47452,-0.47452,-0.47452,-0.47452,-0.47452,-0.47452,-0.47452,-0.47452,-0.462605,-0.462605,-0.462605,-0.462605,-0.486833,-0.486833,-0.486833,-0.486833,-0.486833,-0.467941,-0.467941,-0.467941,-0.467941,-0.467941,-0.509574,-0.509574,-0.509574,-0.366473,-0.366473,-0.366473,-0.317394,-0.317394,-0.317394,-0.222116,-0.222116,-0.222116]
}

# %%
df = pd.DataFrame(dict)
df = df.set_index('SMAs')
df
# Out:
#         CumProd Diff
# SMAs
# 2-8        -0.269355
# 4-8        -0.269355
# 2-24       -0.299594
# 4-24       -0.299594
# 2-50       -0.303224
# 4-50       -0.303224
# 2-80       -0.355966
# 4-80       -0.355966
# 4-100      -0.354796
# 8-100      -0.354796
# 16-100     -0.354796
# 24-100     -0.354796
# 4-120      -0.474520
# 8-120      -0.474520
# 16-120     -0.474520
# 24-120     -0.474520
# 4-140      -0.474520
# 8-140      -0.474520
# 16-140     -0.474520
# 24-140     -0.474520
# 4-160      -0.462605
# 8-160      -0.462605
# 16-160     -0.462605
# 24-160     -0.462605
# 4-200      -0.486833
# 8-200      -0.486833
# 16-200     -0.486833
# 24-200     -0.486833
# 48-200     -0.486833
# 4-300      -0.467941
# 8-300      -0.467941
# 16-300     -0.467941
# 24-300     -0.467941
# 48-300     -0.467941
# 8-400      -0.509574
# 24-400     -0.509574
# 48-400     -0.509574
# 8-500      -0.366473
# 24-500     -0.366473
# 48-500     -0.366473
# 8-600      -0.317394
# 24-600     -0.317394
# ...

# %%
fig = df.plot(figsize=[12,6], rot=90)
fig.set_xticks(np.arange(len(df.index)))
fig.set_xticklabels(df.index)
fig.set_title('Difference Between Average Cumulative Products of Actual Returns and Strategy Returns\nFrom 2019–04 Through 2021–01 for Various SMA Combinations')
fig.figure.savefig('Resources/avg_cumprod_diff_sma.png')
